# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('E:/Wiser/Flipkart data.xlsx', header=None)
df
# Out:
#                                               0  \
# 0                                arabella-dress
# 1                                   bella-dress
# 2                               carter-playsuit
# 3                               charlotte-dress
# 4   daphne-crop-sleeve-wrap-mini-dress-lavender
# 5                              aircontact-65-10
# 6               daphne-easy-days-mini-dress-red
# 7     daphne-easy-days-wrap-maxi-dress-lavender
# 8          daphne-easy-days-wrap-maxi-dress-red
# 9                                 delilah-skirt
# 10      edie-cascade-wrap-mini-dress-dusty-blue
# 11                                    eliza-top
# 12                                 emilia-dress
# 13                                    faith-top
# 14                                  freya-pants
# 15                                   gracie-set
# 16                              harper-playsuit
# 17                                   isla-skirt
# ...

# %%
df.isnull().sum()
# Out:
# 0     0
# 1     4
# 2     5
# 3     6
# 4    10
# dtype: int64

# %%
df.values.tolist()
# Out:
# [['arabella-dress',
#   'daphne-easy-days-wrap-maxi-dress-lavender',
#   'gracie-set',
#   'valentina-fiesta-wrap-maxi-dress-off-white',
#   'mila-skirt'],
#  ['bella-dress',
#   'eliza-top',
#   'scarlett-baby-doll-mini-dress-blush',
#   'zara-shorts',
#   'quinn-skirt'],
#  ['carter-playsuit',
#   'faith-top',
#   'scarlett-fine-dress-black',
#   'zena-dress',
#   'rumi-dress'],
#  ['charlotte-dress',
#   'marley-skirt',
#   'eliza-top',
#   'daphne-easy-days-wrap-maxi-dress-lavender',
#   'scarlett-baby-doll-mini-dress-blush'],
#  ['daphne-crop-sleeve-wrap-mini-dress-lavender',
#   'carter-playsuit',
#   'faith-top',
#   'aircontact-65-10',
#   'lily-dress'],
#  ['aircontact-65-10',
#   'charlotte-dress',
#   'freya-pants',
#   'daphne-easy-days-mini-dress-red',
#   nan],
#  ['daphne-easy-days-mini-dress-red',
#   'marley-skirt',
#   'daphne-easy-days-wrap-maxi-dress-lavender',
#   'daphne-easy-days-wrap-maxi-dress-lavender',
#   nan],
# ...

# %%
T = []
for i in range(len(df)):
    T.append([str(df.values[i,j]) for j in range(0,4) if str(df.values[i,j])!='nan'])

# %%
T
# Out:
# [['arabella-dress',
#   'daphne-easy-days-wrap-maxi-dress-lavender',
#   'gracie-set',
#   'valentina-fiesta-wrap-maxi-dress-off-white'],
#  ['bella-dress',
#   'eliza-top',
#   'scarlett-baby-doll-mini-dress-blush',
#   'zara-shorts'],
#  ['carter-playsuit', 'faith-top', 'scarlett-fine-dress-black', 'zena-dress'],
#  ['charlotte-dress',
#   'marley-skirt',
#   'eliza-top',
#   'daphne-easy-days-wrap-maxi-dress-lavender'],
#  ['daphne-crop-sleeve-wrap-mini-dress-lavender',
#   'carter-playsuit',
#   'faith-top',
#   'aircontact-65-10'],
#  ['aircontact-65-10',
#   'charlotte-dress',
#   'freya-pants',
#   'daphne-easy-days-mini-dress-red'],
#  ['daphne-easy-days-mini-dress-red',
#   'marley-skirt',
#   'daphne-easy-days-wrap-maxi-dress-lavender',
#   'daphne-easy-days-wrap-maxi-dress-lavender'],
#  ['daphne-easy-days-wrap-maxi-dress-lavender',
#   'scarlett-baby-doll-mini-dress-blush',
#   'daphne-easy-days-wrap-maxi-dress-red'],
#  ['daphne-easy-days-wrap-maxi-dress-red',
# ...

# %%
pip install apyori
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5979 sha256=37f83e9e0a1b8b31b6b13a60e9f80894662ba250ed7da125a5276896eccc17c3
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\1b\02\6c\a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# ...

# %%
from apyori import apriori
rules = apriori(T,min_support=0.03,min_confidence=0.35,min_lift=2,min_length=3)

# %%
list(rules)
# Out:
# [RelationRecord(items=frozenset({'carter-playsuit', 'faith-top'}), support=0.04081632653061224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carter-playsuit'}), items_add=frozenset({'faith-top'}), confidence=0.6666666666666666, lift=2.7222222222222223)]),
#  RelationRecord(items=frozenset({'daphne-easy-days-wrap-maxi-dress-lavender', 'edie-cascade-wrap-mini-dress-dusty-blue'}), support=0.04081632653061224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'edie-cascade-wrap-mini-dress-dusty-blue'}), items_add=frozenset({'daphne-easy-days-wrap-maxi-dress-lavender'}), confidence=0.39999999999999997, lift=2.1777777777777776)]),
#  RelationRecord(items=frozenset({'madison-top', 'daphne-easy-days-wrap-maxi-dress-lavender'}), support=0.04081632653061224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'madison-top'}), items_add=frozenset({'daphne-easy-days-wrap-maxi-dress-lavender'}), confidence=0.6666666666666666, lift=3.6296296296296293)]),
# ...

# %%
rules1 = apriori(T,min_support=0.03,min_confidence=0.35,min_lift=3,min_length=3)

# %%
list(rules1)
# Out:
# [RelationRecord(items=frozenset({'madison-top', 'daphne-easy-days-wrap-maxi-dress-lavender'}), support=0.04081632653061224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'madison-top'}), items_add=frozenset({'daphne-easy-days-wrap-maxi-dress-lavender'}), confidence=0.6666666666666666, lift=3.6296296296296293)]),
#  RelationRecord(items=frozenset({'valentina-fiesta-wrap-maxi-dress-off-white', 'daphne-easy-days-wrap-maxi-dress-lavender'}), support=0.04081632653061224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'valentina-fiesta-wrap-maxi-dress-off-white'}), items_add=frozenset({'daphne-easy-days-wrap-maxi-dress-lavender'}), confidence=0.6666666666666666, lift=3.6296296296296293)]),
# ...
